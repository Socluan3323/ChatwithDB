# %%
from crud import *

# %%
init_schema()
# Out:
# 2025-12-06 14:21:21,498 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-12-06 14:21:21,499 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-06 14:21:21,504 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-12-06 14:21:21,505 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-06 14:21:21,507 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-12-06 14:21:21,508 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-06 14:21:21,512 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:21:21,516 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s::VARCHAR AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s::VARCHAR, %(param_2)s::VARCHAR, %(param_3)s::VARCHAR, %(param_4)s::VARCHAR, %(param_5)s::VARCHAR]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s::VARCHAR
# 2025-12-06 14:21:21,516 INFO sqlalchemy.engine.Engine [generated in 0.00072s] {'table_name': 'products', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-12-06 14:21:21,521 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s::VARCHAR AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s::VARCHAR, %(param_2)s::VARCHAR, %(param_3)s::VARCHAR, %(param_4)s::VARCHAR, %(param_5)s::VARCHAR]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s::VARCHAR
# 2025-12-06 14:21:21,522 INFO sqlalchemy.engine.Engine [cached since 0.006388s ago] {'table_name': 'product_types', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-12-06 14:21:21,525 INFO sqlalchemy.engine.Engine COMMIT

# %%
productype_id_to_name = {
    "FP" : "thuc pham",
    "DR" : "do uong",
    "HG" : "do gia dung",
    "EL" : "thiet bi dien tu",
    "CS" : "my pham"
}
productype_name_to_id = {
    "thuc pham" : "FP",
    "do uong" : "DR",
    "do gia dung" : "HG",
    "thiet bi dien tu" : "EL",
    "my pham" : "CS"
}

# %%
for type_id,type_name in productype_id_to_name.items():
    a = ProductType(id= type_id,name= type_name)
    insert_one_productType(a)
# Out:
# 2025-12-06 14:21:26,917 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:21:26,919 INFO sqlalchemy.engine.Engine SELECT product_types.id AS product_types_id, product_types.name AS product_types_name
# FROM product_types
# WHERE product_types.id = %(pk_1)s::VARCHAR
# 2025-12-06 14:21:26,919 INFO sqlalchemy.engine.Engine [generated in 0.00078s] {'pk_1': 'FP'}
# 2025-12-06 14:21:26,936 INFO sqlalchemy.engine.Engine SELECT products.type_id AS products_type_id, products.id AS products_id, products.name AS products_name, products.price AS products_price, products.quantity AS products_quantity
# FROM products
# WHERE products.type_id IN (%(primary_keys_1)s::VARCHAR)
# 2025-12-06 14:21:26,937 INFO sqlalchemy.engine.Engine [generated in 0.00082s] {'primary_keys_1': 'FP'}
# 2025-12-06 14:21:26,939 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-12-06 14:21:26,940 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:21:26,941 INFO sqlalchemy.engine.Engine SELECT product_types.id AS product_types_id, product_types.name AS product_types_name
# FROM product_types
# WHERE product_types.id = %(pk_1)s::VARCHAR
# 2025-12-06 14:21:26,941 INFO sqlalchemy.engine.Engine [cached since 0.02292s ago] {'pk_1': 'DR'}
# 2025-12-06 14:21:26,945 INFO sqlalchemy.engine.Engine INSERT INTO product_types (id, name) VALUES (%(id)s::VARCHAR, %(name)s::VARCHAR)
# 2025-12-06 14:21:26,946 INFO sqlalchemy.engine.Engine [generated in 0.00111s] {'id': 'DR', 'name': 'do uong'}
# 2025-12-06 14:21:26,948 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:21:26,951 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:21:26,952 INFO sqlalchemy.engine.Engine SELECT product_types.id AS product_types_id, product_types.name AS product_types_name
# FROM product_types
# WHERE product_types.id = %(pk_1)s::VARCHAR
# 2025-12-06 14:21:26,953 INFO sqlalchemy.engine.Engine [cached since 0.03433s ago] {'pk_1': 'HG'}
# 2025-12-06 14:21:26,956 INFO sqlalchemy.engine.Engine INSERT INTO product_types (id, name) VALUES (%(id)s::VARCHAR, %(name)s::VARCHAR)
# 2025-12-06 14:21:26,957 INFO sqlalchemy.engine.Engine [cached since 0.01131s ago] {'id': 'HG', 'name': 'do gia dung'}
# 2025-12-06 14:21:26,959 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:21:26,962 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:21:26,963 INFO sqlalchemy.engine.Engine SELECT product_types.id AS product_types_id, product_types.name AS product_types_name
# FROM product_types
# WHERE product_types.id = %(pk_1)s::VARCHAR
# 2025-12-06 14:21:26,963 INFO sqlalchemy.engine.Engine [cached since 0.04442s ago] {'pk_1': 'EL'}
# 2025-12-06 14:21:26,965 INFO sqlalchemy.engine.Engine INSERT INTO product_types (id, name) VALUES (%(id)s::VARCHAR, %(name)s::VARCHAR)
# 2025-12-06 14:21:26,966 INFO sqlalchemy.engine.Engine [cached since 0.0204s ago] {'id': 'EL', 'name': 'thiet bi dien tu'}
# 2025-12-06 14:21:26,967 INFO sqlalchemy.engine.Engine COMMIT
# 2025-12-06 14:21:26,970 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-06 14:21:26,971 INFO sqlalchemy.engine.Engine SELECT product_types.id AS product_types_id, product_types.name AS product_types_name
# FROM product_types
# WHERE product_types.id = %(pk_1)s::VARCHAR
# 2025-12-06 14:21:26,971 INFO sqlalchemy.engine.Engine [cached since 0.05287s ago] {'pk_1': 'CS'}
# 2025-12-06 14:21:26,974 INFO sqlalchemy.engine.Engine INSERT INTO product_types (id, name) VALUES (%(id)s::VARCHAR, %(name)s::VARCHAR)
# 2025-12-06 14:21:26,975 INFO sqlalchemy.engine.Engine [cached since 0.02949s ago] {'id': 'CS', 'name': 'my pham'}
# 2025-12-06 14:21:26,976 INFO sqlalchemy.engine.Engine COMMIT
